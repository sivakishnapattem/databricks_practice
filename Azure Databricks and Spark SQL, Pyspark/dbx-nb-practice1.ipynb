# %%
path = '/Volumes/population_metrics/landing/datasets/countries_dataset/countries_dataset/csv_data/countries_population/countries_population.csv'

# %%
df = spark.read.csv(path, header=True, inferSchema=True)
display(df)

# %%
df = spark.read.load(path, format = 'csv', header = True, inferSchema = True)
display(df)

# %%
schema1 = """
    country_id int,
    name string,
    nationality string,
    country_code string,
    iso_alpha2 string,
    capital string,
    population int,
    area_km2 double,
    region_id int,
    sub_region_id int"""

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

schema2 = StructType([
    StructField('country_id', IntegerType(), False),
    StructField('name', StringType(), True),
    StructField('nationality', StringType(), True),
    StructField('country_code', StringType(), True),
    StructField('iso_alpha2', StringType(), True),
    StructField('capital', StringType(), True),
    StructField('population', IntegerType(), True),
    StructField('area_km2', DoubleType(), True),
    StructField('region_id', IntegerType(), True),
    StructField('sub_region_id', IntegerType(), True)
])

# %%
partition_path = '/Volumes/population_metrics/landing/datasets/countries_dataset/countries_dataset/csv_data/countries_population_partitioned/'

df1 = spark.read.format('csv').options(header=True).schema(schema2).load(partition_path)
display(df1)

# %%
df1.dtypes

# %%
output_path = '/Volumes/population_metrics/landing/datasets/countries_dataset/output_dataset/csv/countries_population'

# %%
df1.write.options(header=True).csv(output_path)

# %%
df.write.mode('append').options(header=True).format('csv').save(output_path)

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

schema2 = StructType([
    StructField('country_id', IntegerType(), False),
    StructField('name', StringType(), True),
    StructField('nationality', StringType(), True),
    StructField('country_code', StringType(), True),
    StructField('iso_alpha2', StringType(), True),
    StructField('capital', StringType(), True),
    StructField('population', IntegerType(), True),
    StructField('area_km2', DoubleType(), True),
    StructField('region_id', IntegerType(), True),
    StructField('sub_region_id', IntegerType(), True)
])

df = spark.read.format('csv').schema(schema2).options(header = True).load('/Volumes/population_metrics/landing/datasets/countries_dataset/countries_dataset/csv_data/countries_population/countries_population.csv')

json_output_path = '/Volumes/population_metrics/landing/datasets/countries_dataset/output_dataset/json/countries_population'

df.write.mode('overwrite').format('json').save(json_output_path)

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType


schema2 = StructType([
    StructField('country_id', IntegerType(), False),
    StructField('name', StringType(), True),
    StructField('nationality', StringType(), True),
    StructField('country_code', StringType(), True),
    StructField('iso_alpha2', StringType(), True),
    StructField('capital', StringType(), True),
    StructField('population', IntegerType(), True),
    StructField('area_km2', DoubleType(), True),
    StructField('region_id', IntegerType(), True),
    StructField('sub_region_id', IntegerType(), True)])

df4 = spark.read.format('json').schema(schema2).load(json_output_path)

df4.display()

# %%
df4.write.mode('append').save('/Volumes/population_metrics/landing/datasets/countries_dataset/output_dataset/orc/countries_population')

# %%
df5 = spark.read.load('/Volumes/population_metrics/landing/datasets/countries_dataset/output_dataset/orc/countries_population')

df5.display()

# %%
df5.write.mode('overwrite').format('parquet').save('/Volumes/population_metrics/landing/datasets/countries_dataset/output_dataset/parquet/countries_population')
df5 = spark.read.format('parquet').load('/Volumes/population_metrics/landing/datasets/countries_dataset/output_dataset/parquet/countries_population')
df5.display()

# %%
df5.write.format('delta').save('/Volumes/population_metrics/landing/datasets/countries_dataset/output_dataset/delta/countries_population')

# %%
df6 = spark.read.format('delta').load('/Volumes/population_metrics/landing/datasets/countries_dataset/output_dataset/delta/countries_population')
df6.display()

# %%
df6.show(n= 200)
